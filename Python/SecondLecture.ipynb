# %% [markdown]
# ```python
# if condicao:
#     instrucao
# else: #opcional
#     instrucao
# ```

# %%
num = int(input("Informe um número: "))

if num > 20:
    print("Maior que 20!")
# Out:
# Maior que 20!

# %% [markdown]
# *Faça um programa que leia um número inteiro; se for maior que 20, multiplique por 2; senão, multiplique por 4. Ao final, imprima o resultado.*

# %%
num = int(input("Informe um número: "))

if num > 20:
    resul = num*2
    print(f"Resultado: {resul}")
else:
    resul = num * 4
    print(f"Resultado: {resul}")
# Out:
# Resultado: 8

# %%
num = int(input("Informe um número: "))

if num > 20:
    resul = num*2
else:
    resul = num * 4

print(f"Resultado: {resul}")
# Out:
# Resultado: 16

# %% [markdown]
# *Leia o cargo (código de 1 a 4) e o salário atual de um funcionário, e calcule o reajuste conforme a tabela: 1-Auxiliar (7%), 2-Secretário (9%), 3-Cozinheiro (5%), 4-Entregador (12%). Imprima o reajuste e o novo salário.*

# %%
cargo = int(input("Digite o cargo do funcionario: "))
sal_atual = float(input("Digite o salário atual: "))

if cargo == 1:
    reaj = (sal_atual * 7)/100
elif cargo == 2:
    reaj = (sal_atual * 9)/100
elif cargo == 3:
    reaj = (sal_atual * 5)/100
else:
    reaj = (sal_atual * 12)/100

print(f"O resjuste foi de: {reaj:.2f}")
print(f"O salário após reajuste: {sal_atual + reaj:.2f}")
# Out:
# O resjuste foi de: 50.00
# O salário após reajuste: 1050.00

# %% [markdown]
# *Um doador de sangue deve ter entre 16 e 69 anos, pesar pelo menos 50 kg, estar bem alimentado e não estar resfriado. Leia esses dados e diga se a pessoa está apta a doar.*

# %%
nome = input("Informe o nome: ")
peso = float(input("Informe o peso: "))
idade = int(input("Digite sua idade: "))
bem_al = input("Está bem alimentado? <S/N>: ").upper() =="S"
resfriado = input("Está resfriado: <S/N>: ").upper() == "S"

if 16 <= idade <= 69 and peso >= 50 and bem_al and not resfriado:
    print(f"O valuntário {nome} está apto!")
else:
    print(f"O valuntário {nome} não está apto!")
# Out:
# O valuntário Yan está apto!

# %% [markdown]
# *Calcule o peso ideal de uma pessoa a partir da altura e do sexo: homens, `(72.7 * altura) - 58`; mulheres, `(62.1 * altura) - 44.7`.*

# %%
sexo = input("Digite seu sexo: <M/F>").upper() == "M"
altura = float(input("Digite sua altura: "))

if sexo:
    peso = (72.7 * altura) - 58
else:
    peso = (62.1 * altura) - 44.7

print(f"Seu peso ideal é: {peso:.2f}")
# Out:
# Seu peso ideal é: 60.87

# %% [markdown]
# #### Exercícios

# %% [markdown]
# 1. **[P]** Leia um número e imprima se ele é positivo, negativo ou zero.

# %%
num = int(input("Digite um número: "))

if num > 0:
    print("Positivo!")
elif num == 0:
    print("Zero.")
else:
    print("Negativo!")
# Out:
# Negativo!

# %% [markdown]
# 2. **[P]** Leia dois números inteiros e imprima o maior deles, sem usar a função `max()`.

# %%
n1 = int(input("Digite um número: "))
n2 = int(input("Digite um número: "))

if n1 > n2:
    print(f"{n1} é maior!")
else:
    print(f"{n2} é maior!")
# Out:
# 2 é maior!

# %% [markdown]
# 9. **[MN]** Uma iteração do método de Newton-Raphson para $f(x) = x^2 - 2$ produz $x_1 = x_0 - \dfrac{f(x_0)}{f'(x_0)}$. Leia $x_0$ e uma tolerância `tol`, calcule $x_1$ e informe se a iteração **convergiu** (isto é, se $|x_1 - x_0| < tol$) ou não.

# %%
x0 = float(input("Informe o valor inicial: "))
tol = float(input("Informe a tolerância: "))

if x0 == 0:
    print("Valor inválido!")

x1 = x0 - (x0**2 - 2)/(2*x0)

if abs(x1 - x0) > tol:
    print("Não convergiu!")
else:
    print("Convergiu!")
# Out:
# Convergiu!

# %% [markdown]
# 10. **[MN]** No método da bisseção, dado um intervalo $[a, b]$ e $f(x) = x^3 - x - 2$, calcule o ponto médio $m = \dfrac{a+b}{2}$ e os valores $f(a)$, $f(b)$ e $f(m)$. Usando o sinal do produto $f(a) \cdot f(m)$, decida (com `if`) se a raiz está em $[a, m]$ ou em $[m, b]$, e imprima o novo intervalo a ser considerado na próxima iteração.

# %%
a = float(input("Digite o valor inicial do intervalo: "))
b = float(input("Digite o valor final do intervalo: "))

m = (a+b)/2

fa = a**3 - a - 2
fb = b**3 - b - 2
fm = m**3 - m - 2

if fa*fm < 0:
    print(f"A raiz está entre [{a}, {m}]")
else:
    print(f"A raiz está entre [{m}, {b}]")
# Out:
# A raiz está entre [0.5, 1.0]

# %% [markdown]
# 13. **[MEF]** *Localização de ponto em elemento finito 1D.* Um domínio unidimensional (uma barra) foi discretizado em 3 elementos finitos lineares, com nós nas coordenadas $x_0=0$, $x_1=2$, $x_2=5$ e $x_3=10$ (metros) — o elemento 1 vai de $x_0$ a $x_1$, o elemento 2 de $x_1$ a $x_2$, e o elemento 3 de $x_2$ a $x_3$. Leia a coordenada $x$ de um ponto qualquer do domínio e, usando `if`/`elif`, determine em qual dos três elementos ele se encontra. Em seguida, calcule sua coordenada local (natural) $\xi \in [-1, 1]$ dentro do elemento identificado, usando $\xi = \dfrac{2(x - x_{esq})}{x_{dir} - x_{esq}} - 1$, em que $x_{esq}$ e $x_{dir}$ são os nós à esquerda e à direita do elemento encontrado. Essa é a primeira operação de qualquer análise por Elementos Finitos: antes de interpolar qualquer grandeza (deslocamento, temperatura, etc.) dentro de um elemento, é preciso localizar em qual elemento está o ponto de interesse.

# %%
x = float(input("Digite um valor x pertencente a [0, 10]: "))

if 0 <= x <= 2:
    print("x está no elemento 1!")
    ksi = (2*(x - 0)) / (2 - 0) - 1
    print(f"O valor: {ksi:.2f}")
elif 2 <= x <= 5:
    print("x está no elemento 2!")
    ksi = (2*(x - 2)) / (5 - 2) - 1
    print(f"O valor: {ksi:.2f}")
elif 5 <= x <= 10:
    print("x está no elemento 3!")
    ksi = (2*(x - 5))/(10 - 5) - 1
    print(f"O valor: {ksi:.2f}")
# Out:
# x está no elemento 2!
# O valor: 1.00
